# %% [markdown]
# Gensim in NLP is a Python library used to build and analyze topic models and word embeddings from large text corpora.
#
# In short: 👉 Gensim helps machines understand text meaning, not just words.
#
# 🔹 What exactly is Gensim?
#
# Gensim is an open-source NLP library designed for:
#
# Topic modeling
#
# Document similarity
#
# Word embeddings
#
# 🔹 What is Gensim used for?
# 1️⃣ Word Embeddings
#
# Converts words into vectors that capture semantic meaning
#
# 2️⃣ Topic Modeling
#
# Automatically finds hidden topics in documents.
#
# Example:
#
# News articles → politics, sports, tech
#
# Reviews → service, price, quality
#
# 3️⃣ Document Similarity
#
# Used to:
#
# Detect plagiarism
#
# Recommend similar articles
#
# Search engines

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 24.0 MB/s  0:00:01m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gensim]2m1/2 [gensim]
# ...

# %%
import gensim

# %% [markdown]
# In this we used Google Word2Vec Pre-trained Model

# %% [markdown]
# 🔹 What is Google Word2Vec Pre-trained Model?
#
# Google Word2Vec is a ready-made (pre-trained) word embedding model created by Google using the Word2Vec algorithm.
#
# In simple words:
# 👉 It already knows meanings and relationships between words, so you don’t have to train it from scratch.
#
# 🧠 What does “pre-trained” mean?
#
# Google trained this model on a huge dataset (Google News):
#
# 📰 ~100 billion words
#
# 📦 ~3 million unique words
#
# 📐 Each word → 300-dimensional vector

# %% [markdown]
# ### IN Next video we train from scratch.

# %%
from gensim.models import Word2Vec,KeyedVectors

# %%
# Using Google Word2Vec Pre trained Model
import gensim.downloader as api
wv=api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king=wv['king']
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
vec_king.shape
# Out:
# (300,)

# %%
wv['happy']
# Out:
# array([-5.18798828e-04,  1.60156250e-01,  1.60980225e-03,  2.53906250e-02,
#         9.91210938e-02, -8.59375000e-02,  3.24218750e-01, -2.17285156e-02,
#         1.34765625e-01,  1.10351562e-01, -1.04980469e-01, -2.90527344e-02,
#        -2.38037109e-02, -4.02832031e-02, -3.68652344e-02,  2.32421875e-01,
#         3.20312500e-01,  1.01074219e-01,  5.83496094e-02, -2.91824341e-04,
#        -3.29589844e-02,  2.11914062e-01,  4.32128906e-02, -8.59375000e-02,
#         2.81250000e-01, -1.78222656e-02,  3.79943848e-03, -1.71875000e-01,
#         2.06054688e-01, -1.85546875e-01,  3.73535156e-02, -1.21459961e-02,
#         2.04101562e-01, -3.80859375e-02,  3.61328125e-02, -8.15429688e-02,
#         8.44726562e-02,  9.37500000e-02,  1.44531250e-01,  7.42187500e-02,
#         2.51953125e-01, -7.91015625e-02,  8.69140625e-02,  1.58691406e-02,
#         1.09375000e-01, -2.23632812e-01, -5.15747070e-03,  1.68945312e-01,
# ...

# %%
# Finding Simiar word with probabiltiy of similarity
wv.most_similar('cricket')
# Out:
# [('cricketing', 0.8372224569320679),
#  ('cricketers', 0.8165745139122009),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
wv.most_similar('happy')
# Out:
# [('glad', 0.7408890724182129),
#  ('pleased', 0.6632170677185059),
#  ('ecstatic', 0.6626912355422974),
#  ('overjoyed', 0.6599286794662476),
#  ('thrilled', 0.6514049172401428),
#  ('satisfied', 0.6437949538230896),
#  ('proud', 0.636042058467865),
#  ('delighted', 0.627237856388092),
#  ('disappointed', 0.6269949674606323),
#  ('excited', 0.6247665286064148)]

# %%
##check similarity b/t two words
wv.similarity('happy','cricket')
# Out:
# 0.10414834

# %%
# to give output as queen
vec=wv['king']-wv['Men']+wv['women']

# %%
wv.most_similar([vec]) #This prove Output of vec is queen
# Out:
# [('king', 0.7368454933166504),
#  ('queen', 0.5782653093338013),
#  ('monarch', 0.5473669767379761),
#  ('kings', 0.5288615226745605),
#  ('crown_prince', 0.5043010115623474),
#  ('prince', 0.49853259325027466),
#  ('princess', 0.4981265664100647),
#  ('Prince_Paras', 0.4915415346622467),
#  ('sultan', 0.4866739511489868),
#  ('ruler', 0.4681279957294464)]
